# %%
import pandas as pd
import re

# Funciones de limpieza
def DF_drop_by_indx(df, lst, indx):
    return df.drop(lst, inplace = True, axis = indx)


# En primer lugar mi data set consta de 2 .csv
df_beers = pd.read_csv('Inputs/beers.csv')
df_breweries = pd.read_csv('Inputs/breweries.csv')

# Limpieza básica del df_beers
lst_colmn_beers = ['abv', 'ibu', 'Unnamed: 0', 'id']
DF_drop_by_indx (df_beers, lst_colmn_beers, 1)

lst_row_beers = [566, 1554, 1555]
DF_drop_by_indx (df_beers, lst_row_beers, 0)

df_beers.loc[853, 'style'] = 'Scotch Ale'
df_beers.loc[853, 'name'] = 'Kilt Lifter'
df_beers.loc[866, 'style'] = 'Oktoberfest'

# Limpieza básica del df_breweries
df_breweries.rename(columns = {'Unnamed: 0': 'brewery_id',
                              'name': 'brewery_name'}, inplace=True)

# Creación del nuevo dataset
df_combine = pd.merge(df_beers, df_breweries, how = 'inner', on = 'brewery_id')
DF_drop_by_indx (df_combine, 'brewery_id', 1)
display(df_combine.head())

df_combine.to_csv('Outputs/combine.csv')
# Out:
#                   name                           style  ounces  \
# 0             Pub Beer             American Pale Lager    12.0
# 1          Devil's Cup         American Pale Ale (APA)    12.0
# 2  Rise of the Phoenix                    American IPA    12.0
# 3             Sinister  American Double / Imperial IPA    12.0
# 4        Sex and Candy                    American IPA    12.0
#
#                 brewery_name  city state
# 0  10 Barrel Brewing Company  Bend    OR
# 1        18th Street Brewery  Gary    IN
# 2        18th Street Brewery  Gary    IN
# 3        18th Street Brewery  Gary    IN
# 4        18th Street Brewery  Gary    IN

# %%
# Más funciones de limpieza:
def sub_to_nothing (df, column, lstcc):
    for e in lstcc:
        df[column] = df[column].str.replace (e, '')
    return df

def change_val (df, column, lst_ch, ch_lst):
    for i, e in enumerate (lst_ch):
        df.loc[(df[column] == e), column] = ch_lst[i]
    return df

# No me funciona value_counts así que me la creo:
def unique_val_count (df, column):
    dicti={}
    for e in df[column]:
        dicti[e]=dicti.get(e,0)+1
    sort_dicti = sorted(dicti.items(), key=lambda kv: kv[1], reverse=True)
    return sort_dicti

# %%
lst_cc = ['\(.+\)','American','Belgian','Baltic','Berliner','English',
          'German','Czech','Euro','Munich','Viena','^\s','\s$']

df_combine = sub_to_nothing(df_combine, 'style', lst_cc)

lst_change = ['IPA', 'Pilsener', 'Pale Wheat Ale']
change_lst = ['India Pale Ale', 'Pilsner', 'Wheat Ale']
change_val(df_combine, 'style', lst_change, change_lst)
# Out:
#                                              name                   style  \
# 0                                        Pub Beer              Pale Lager
# 1                                     Devil's Cup                Pale Ale
# 2                                  India Pale Ale          India Pale Ale
# 3                                        Sinister   Double / Imperial IPA
# 4                                  India Pale Ale          India Pale Ale
# 5                                    Black Exodus           Oatmeal Stout
# 6                             Lake Street Express                Pale Ale
# 7                                         Foreman                  Porter
# 8                                            Jade                Pale Ale
# 9                                    Cone Crusher   Double / Imperial IPA
# 10                              Sophomoric Saison  Saison / Farmhouse Ale
# 11                          Regional Ring Of Fire  Saison / Farmhouse Ale
# 12                                     Garce Selé  Saison / Farmhouse Ale
# 13                                 India Pale Ale          India Pale Ale
# 2403              CO
# 2404              CO
# 2405              CO
# 2406              CO
#
# [2407 rows x 6 columns]

# %%
# df_combine['style'].value_counts

unique_val_count(df_combine, 'style')
# IPA -> India Pale Ale
# Pilsener -> Pilsner
# Rye Beer
# Cider
# California Common / Steam Beer
# Out:
# [('India Pale Ale', 455),
#  ('Pale Ale', 281),
#  ('Amber / Red Ale', 133),
#  ('Blonde Ale', 108),
#  ('Double / Imperial IPA', 105),
#  ('Wheat Ale', 98),
#  ('Pilsner', 89),
#  ('Brown Ale', 88),
#  ('Porter', 74),
#  ('Saison / Farmhouse Ale', 52),
#  ('Witbier', 51),
#  ('Fruit / Vegetable Beer', 49),
#  ('Kölsch', 42),
#  ('Pale Lager', 41),
#  ('Stout', 41),
#  ('Hefeweizen', 40),
#  ('Cider', 37),
#  ('Black Ale', 36),
#  ('Märzen / Oktoberfest', 30),
#  ('Amber / Red Lager', 29),
#  ('Cream Ale', 29),
#  ('Pumpkin Ale', 23),
#  ('Vienna Lager', 20),
#  ('Helles Lager', 20),
#  ('Extra Special / Strong Bitter', 20),
#  ('Scottish Ale', 19),
#  ('Oatmeal Stout', 18),
#  ('Strong Ale', 18),
#  ('Rye Beer', 18),
#  ('Adjunct Lager', 18),
#  ('Winter Warmer', 15),
#  ('Scotch Ale / Wee Heavy', 15),
#  ('Altbier', 13),
#  ('Irish Red Ale', 12),
#  ('Light Lager', 12),
#  ('Tripel', 11),
#  ('Dark Ale', 11),
#  ('Weissbier', 11),
#  ('White IPA', 11),
#  ('Russian Imperial Stout', 11),
#  ('Milk / Sweet Stout', 10),
#  ('Gose', 10),
#  ('Double / Imperial Stout', 9),
#  ('Schwarzbier', 9),
#  ('Herbed / Spiced Beer', 9),
#  ('Bock', 7),
#  ('Bière de Garde', 7),
#  ('Doppelbock', 7),
#  ('Strong Pale Ale', 7),
#  ('Dark Wheat Ale', 7),
#  ('Barleywine', 6),
#  ('Strong Dark Ale', 6),
#  ('Wild Ale', 6),
#  ('California Common / Steam Beer', 6),
#  ('Foreign / Export Stout', 6),
#  ('Dortmunder / Export Lager', 6),
#  ('Dark Mild Ale', 6),
#  ('Dark Lager', 5),
#  ('Mead', 5),
#  ('Irish Dry Stout', 5),
#  ('Dubbel', 5),
#  ('Maibock / Helles Bock', 5),
#  ('Dunkel Lager', 4),
#  ('Dunkelweizen', 4),
#  ('Quadrupel', 4),
#  ('Radler', 3),
#  ('Pale Mild Ale', 3),
#  ('Keller Bier / Zwickel Bier', 3),
#  ('India Pale Lager', 3),
#  ('Shandy', 3),
#  ('Bitter', 3),
#  ('Chile Beer', 3),
#  ('Rauchbier', 2),
#  ('Abbey Single Ale', 2),
#  ('Roggenbier', 2),
#  ('Old Ale', 2),
#  ('Double / Imperial Pilsner', 2),
#  ('Other', 1),
#  ('Smoked Beer', 1),
#  ('Kristalweizen', 1),
#  ('Scotch Ale', 1),
#  ('Oktoberfest', 1),
#  ('Flanders Red Ale', 1),
#  ('Malt Liquor', 1),
#  ('Grisette', 1),
#  ('Flanders Oud Bruin', 1),
#  ('Braggot', 1),
#  ('Low Alcohol Beer', 1)]
