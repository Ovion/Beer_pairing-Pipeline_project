# %%
import pandas as pd

# %%
df_cc = pd.read_csv ('Outputs/combine_code_cc.csv')
df_cc.drop('Unnamed: 0', inplace = True, axis = 1)
df_scrapp = pd.read_csv ('Outputs/scrapp_code.csv')

# %%
df_cc
# Out:
#                                              name                  style  \
# 0                                        Pub Beer                 Others
# 1                                     Devil's Cup               Pale Ale
# 2                             Rise of the Phoenix         India Pale Ale
# 3                                        Sinister  Double / Imperial IPA
# 4                                   Sex and Candy         India Pale Ale
# 5                                    Black Exodus          Oatmeal Stout
# 6                             Lake Street Express               Pale Ale
# 7                                         Foreman                 Porter
# 8                                            Jade               Pale Ale
# 9                                    Cone Crusher  Double / Imperial IPA
# 10                              Sophomoric Saison                 Others
# 11                          Regional Ring Of Fire                 Others
# ...

# %%
df_scrapp
# Out:
#                     Estilo                                             Platos  \
# 0                  Kölsch      Comida liviana, pollo, ensaladas, salchichas.
# 1                Cream Ale      Comida liviana, pollo, ensaladas, salchichas.
# 2               Blonde Ale      Comida liviana, pollo, ensaladas, salchichas.
# 3     British-Style Bitter       Pollo o cerdo asado, pescado y papas fritas.
# 4                 Pale Ale     Pastel de carne, quesos ingleses, hamburgesas.
# 5           India Pale Ale  Comidas fuertes y condimentadas (curry) o tort...
# 6    Double / Imperial IPA  Filete de pechuga ahumada, cordero grillado, f...
# 7          Amber / Red Ale  Pollo, productos del mar, hamburguesas, excele...
# 8   Scotch Ale / Wee Heavy  Filete asado o grillado, cordero, salmón ahum...
# 9                Brown Ale  Comida abundante: cerdo asado, salchichas, sal...
# 10                 Altbier  Comida abundante: cerdo asado, salchichas, sal...
# ...

# %%
lst_states = set([e for e in df_cc['state']])

# %%
df_cc.groupby(['state']).head()
# Out:
#                                          name                  style  ounces  \
# 0                                    Pub Beer                 Others    12.0
# 1                                 Devil's Cup               Pale Ale    12.0
# 2                         Rise of the Phoenix         India Pale Ale    12.0
# 3                                    Sinister  Double / Imperial IPA    12.0
# 4                               Sex and Candy         India Pale Ale    12.0
# 5                                Black Exodus          Oatmeal Stout    12.0
# 15                                Ginja Ninja                 Others    12.0
# 16                              Cherried Away                 Others    12.0
# 17                               Rhubarbarian                 Others    12.0
# 18                                BrightCider                 Others    12.0
# 19                He Said Baltic-Style Porter                 Porter    12.0
# ...

# %%
df_scrapp.loc[(df_scrapp['Estilo']=='Cream Ale')]
# Out:
#       Estilo                                         Platos  \
# 1  Cream Ale  Comida liviana, pollo, ensaladas, salchichas.
#
#                                              Postres  \
# 1  Pastel de mandarina o damasco, torta de crema ...
#
#                                               Quesos Temperatura  \
# 1  Monterey Jack, Brick o similar, quesos de sabo...   4,5-7 °C.
#
#        Vaso/Copa
# 1  Vaso Pilsner.

# %%
lst_states
# Out:
# {' AK',
#  ' AL',
#  ' AR',
#  ' AZ',
#  ' CA',
#  ' CO',
#  ' CT',
#  ' DC',
#  ' DE',
#  ' FL',
#  ' GA',
#  ' HI',
#  ' IA',
#  ' ID',
#  ' IL',
#  ' IN',
#  ' KS',
#  ' KY',
#  ' LA',
#  ' MA',
#  ' MD',
#  ' ME',
#  ' MI',
#  ' MN',
#  ' MO',
#  ' MS',
#  ' MT',
#  ' NC',
#  ' ND',
#  ' NE',
#  ' NH',
#  ' NJ',
#  ' NM',
#  ' NV',
#  ' NY',
#  ' OH',
#  ' OK',
#  ' OR',
#  ' PA',
#  ' RI',
#  ' SC',
#  ' SD',
#  ' TN',
#  ' TX',
#  ' UT',
#  ' VA',
#  ' VT',
#  ' WA',
#  ' WI',
#  ' WV',
#  ' WY'}
